# %%
# !kaggle datasets download -d iabhishekofficial/mobile-price-classification -p /users/noneh/mobiledatakaggle
# Out:
# Traceback (most recent call last):
#   File "c:\users\mapraw\anaconda3\lib\runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\users\mapraw\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\Mapraw\anaconda3\Scripts\kaggle.exe\__main__.py", line 4, in <module>
#   File "c:\users\mapraw\anaconda3\lib\site-packages\kaggle\__init__.py", line 23, in <module>
#     api.authenticate()
#   File "c:\users\mapraw\anaconda3\lib\site-packages\kaggle\api\kaggle_api_extended.py", line 164, in authenticate
#     raise IOError('Could not find {}. Make sure it\'s located in'
# OSError: Could not find kaggle.json. Make sure it's located in C:\Users\Mapraw\.kaggle. Or use the environment method.

# %%
import os

# %%
os.chdir('/users/noneh/mobiledatakaggle')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-c97d0d0325c2> in <module>
# ----> 1 os.chdir('/users/noneh/mobiledatakaggle')
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: '/users/noneh/mobiledatakaggle'

# %%
print( os.getcwd() )
# Out:
# C:\Users\Mapraw\Desktop\IoTHW\group_HW\Repo_hw_group

# %%
import zipfile

z= zipfile.ZipFile('mobile-price-classification.zip') 
z.extractall()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-84482f5c2e2a> in <module>
#       1 import zipfile
#       2
# ----> 3 z= zipfile.ZipFile('mobile-price-classification.zip')
#       4 z.extractall()
#
# ~\anaconda3\lib\zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps)
#    1249             while True:
#    1250                 try:
# -> 1251                     self.fp = io.open(file, filemode)
#    1252                 except OSError:
#    1253                     if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'mobile-price-classification.zip'

# %%
import pandas as pd

# %%
testcsv = ('/users/noneh/mobiledata/test.csv')

# %%
dftest = pd.read_csv(testcsv)
dftest
# Out:
#        id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0       1           1043     1          1.8         1  14       0           5
# 1       2            841     1          0.5         1   4       1          61
# 2       3           1807     1          2.8         0   1       0          27
# 3       4           1546     0          0.5         1  18       1          25
# 4       5           1434     0          1.4         0  11       1          49
# 5       6           1464     1          2.9         1   5       1          50
# 6       7           1718     0          2.4         0   1       0          47
# 7       8            833     0          2.4         1   0       0          62
# 8       9           1111     1          2.9         1   9       1          25
# 9      10           1520     0          0.5         0   1       0          25
# 10     11           1500     0          2.2         0   2       0          55
# ...

# %%
traincsv = ('/users/noneh/mobiledata/train.csv')

# %%
dftrain = pd.read_csv(traincsv)
dftrain
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# 5              1859     0          0.5         1   3       0          22
# 6              1821     0          1.7         0   4       1          10
# 7              1954     0          0.5         1   0       0          24
# 8              1445     1          0.5         0   0       0          53
# 9               509     1          0.6         1   2       1           9
# 10              769     1          2.9         1   0       0           9
# 11             1520     1          2.2         0   5       1          33
# ...
